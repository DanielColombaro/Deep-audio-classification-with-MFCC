# %%
# !pip install tensorflow tensorflow-io matplotlib pydub torchutils -qq

# %%
from google.colab import drive
from google.colab import files
import numpy as np
import pandas as pd
import os
import librosa as lr
import math, random
import torch
import torchaudio
from torchaudio import transforms
from IPython.display import Audio
from torch.utils.data import DataLoader, Dataset, random_split
import torch.nn.functional as F
import torch.nn as nn
from torch.nn import init
from datetime import datetime
import torch.optim as optim
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from torchsummary import summary

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
subdir = "gdrive/My Drive/Deep learning/data set progetto"

# %%
classified_data = pd.read_csv(os.path.join(subdir, 'data.csv'))

# %%
from glob import glob
subdir = "gdrive/My Drive/Deep learning/data set progetto/audio"
subdir2 = "gdrive/My Drive/Deep learning/data set progetto/Audio2"
subdir3 = "gdrive/My Drive/Deep learning/data set progetto/audio4"
classified_data = pd.read_csv(os.path.join('gdrive/My Drive/Deep learning/data set progetto/', 'data.csv'))
our_data=glob("gdrive/My Drive/Deep learning/data set progetto/audio/*.wav")
our_data2=glob("gdrive/My Drive/Deep learning/data set progetto/Audio2/*.wav")
our_data3=glob("gdrive/My Drive/Deep learning/data set progetto/audio4/*.wav")

nome_file=[]
label=[]
for i in our_data:
  for j in classified_data['nome_file']:
    if i==os.path.join(subdir, j):
      path = subdir + '/' + i[54:]
      nome_file.append(path)
      label.append(str(list(classified_data[classified_data['nome_file']==j]['label'])))


for i in our_data2:
  for j in classified_data['nome_file']:
    if i==os.path.join(subdir2, j):
      path = subdir2 + '/' + i[55:]
      nome_file.append(path)
      label.append(str(list(classified_data[classified_data['nome_file']==j]['label'])))

for i in our_data3:
  for j in classified_data['nome_file']:
    if i==os.path.join(subdir3, j):
      path = subdir3 + '/' + i[55:]
      nome_file.append(path)
      label.append(str(list(classified_data[classified_data['nome_file']==j]['label'])))

data={'nome_file':nome_file, 'label':label}
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-30fbbdf7698d> in <cell line: 2>()
#       1 subdir = "gdrive/My Drive/Deep learning/data set progetto/audio"
# ----> 2 classified_data = pd.read_csv(os.path.join('gdrive/My Drive/Deep learning/data set progetto/', 'data.csv'))
#       3 our_data=glob("gdrive/My Drive/Deep learning/data set progetto/audio/*.wav")
#       4 our_data2=glob("gdrive/My Drive/Deep learning/data set progetto/Audio2/*.wav")
#       5 our_data3=glob("gdrive/My Drive/Deep learning/data set progetto/audio4/*.wav")
#
# NameError: name 'pd' is not defined

# %%
labelencoder=LabelEncoder()
y=np.array(df['label'].tolist())
labels = to_categorical(labelencoder.fit_transform(y))

# %% [markdown]
# ## BATCH DATALOADER

# %%
class AudioUtil():

  # Load an audio file. Return the signal as a tensor and the sample rate

  @staticmethod
  def open(audio_file):
    sig, sr = torchaudio.load(audio_file)
    return (sig, sr)

  def spectro_gram(aud, n_mels=64, n_fft=1024, hop_len=None):
    sig,sr = aud
    top_db = 80

    # spec has shape [channel, n_mels, time], where channel is mono, stereo etc
    spec = transforms.MelSpectrogram(sr, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(sig)

    # Convert to decibels
    spec = transforms.AmplitudeToDB(top_db=top_db)(spec)
    return (spec)

# %%
class SoundDS():
  def __init__(self, df, labels):
    self.df = df
    self.labels = labels

  # Number of items in dataset

  def __len__(self):
    return len(self.df)


  # Get i'th item in dataset

  def __getitem__(self, idx):
    # Absolute file path of the audio file
    audio_file = self.df.loc[idx, 'nome_file']

    # Get the Class ID
    class_id = self.labels[idx]

    aud = AudioUtil.open(audio_file)
    sgram = AudioUtil.spectro_gram(aud, n_mels=64, n_fft=1024, hop_len=None)
    return sgram, class_id, audio_file

# %%
myds = SoundDS(df, labels)
# Random split of 80:20 between training and validation
num_items = len(myds)
num_train = round(num_items * 0.8)
num_val = num_items - num_train
train_ds, val_ds = random_split(myds, [num_train, num_val])

# Create training and validation data loaders
train_dl = torch.utils.data.DataLoader(train_ds, batch_size=16, shuffle=True)
val_dl = torch.utils.data.DataLoader(val_ds, batch_size=16, shuffle=True)

# %%
next(iter(train_dl))[0].shape
# Out:
# torch.Size([16, 2, 64, 862])

# %%
class AudioClassifier (nn.Module):

    def __init__(self, input_shape, num_classes):
        super(AudioClassifier, self).__init__()
        conv_layers = []

        # First Convolution Block
        self.conv1 = nn.Conv2d(2, 8, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
        self.relu1 = nn.ReLU()
        self.bn1 = nn.BatchNorm2d(8)
        self.conv1.bias.data.zero_()
        conv_layers += [self.conv1, self.relu1, self.bn1]

        # Second Convolution Block
        self.conv2 = nn.Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu2 = nn.ReLU()
        self.bn2 = nn.BatchNorm2d(16)
        self.conv2.bias.data.zero_()
        conv_layers += [self.conv2, self.relu2, self.bn2]

        # Third Convolution Block
        self.conv3 = nn.Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)) # CAMBIATO DA 32 A 64
        self.relu3 = nn.ReLU()
        self.bn3 = nn.BatchNorm2d(32)
        self.conv3.bias.data.zero_()
        conv_layers += [self.conv3, self.relu3, self.bn3]

        # Fourth Convolution Block
        self.conv4 = nn.Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu4 = nn.ReLU()
        self.bn4 = nn.BatchNorm2d(64)

        self.conv4.bias.data.zero_()
        conv_layers += [self.conv4, self.relu4, self.bn4]

        # Linear Classifier
        self.ap = nn.AdaptiveAvgPool2d(output_size=1)
        self.lin = nn.Linear(in_features=64, out_features=num_classes)

        # Wrap the Convolutional Blocks
        self.conv = nn.Sequential(*conv_layers)

    # Forward pass computations

    def forward(self, x):
        # Run the convolutional blocks
        x = self.conv(x)

        # Adaptive pool and flatten for input to linear layer
        x = self.ap(x)
        x = x.view(x.shape[0], -1)

        # Linear layer
        x = self.lin(x)

        return x


# Create the model and put it on the GPU if available
myModel = AudioClassifier(([16,2,64,862]) , 15)

# %%
def training(model, train_dl, num_epochs):
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
  scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.001,
                                                steps_per_epoch=int(len(train_dl)),
                                                epochs=num_epochs,
                                                anneal_strategy='linear')

  avg_loss_list=[]
  acc_list=[]
  # Repeat for each epoch
  for epoch in range(num_epochs):
    running_loss = 0.0
    correct_prediction = 0
    total_prediction = 0

    # Repeat for each batch in the training set
    for i, (inputs, labels, file_path) in enumerate(train_dl):

        inputs_m, inputs_s = inputs.mean(), inputs.std()
        inputs = (inputs - inputs_m) / inputs_s

        optimizer.zero_grad()

        outputs = myModel(inputs)

        loss = criterion(outputs, labels) # labels
        loss.backward()
        optimizer.step()
        scheduler.step()

        running_loss += loss.item()

        _, prediction = torch.max(outputs,1)

        rows, cols = torch.where(labels == 1)

        correct_prediction += (prediction == cols).sum().item()
        total_prediction += prediction.shape[0]


    # Print stats at the end of the epoch
    num_batches = len(train_dl)
    avg_loss = running_loss / num_batches
    avg_loss_list.append(avg_loss)
    acc = correct_prediction/total_prediction
    acc_list.append(acc)
    print(f'Epoch: {epoch}, Loss: {avg_loss:.2f},  Training Accuracy: {acc:.2f}')


  print('Finished Training')


  plt.subplot(1, 2, 1)
  plt.plot(acc_list, label='Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend()
  ax = plt.gca()
  ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

  plt.subplot(1, 2, 2)
  plt.plot(avg_loss_list, ':', color='orange', label='Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  ax = plt.gca()
  ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
  plt.show()


num_epochs=12   # Just for demo, adjust this higher.
prova = training(myModel, train_dl, num_epochs)
# Out:
# Epoch: 0, Loss: 2.58,  Training Accuracy: 0.19
# Epoch: 1, Loss: 2.09,  Training Accuracy: 0.43
# Epoch: 2, Loss: 1.64,  Training Accuracy: 0.55
# Epoch: 3, Loss: 1.31,  Training Accuracy: 0.65
# Epoch: 4, Loss: 1.00,  Training Accuracy: 0.72
# Epoch: 5, Loss: 0.83,  Training Accuracy: 0.78
# Epoch: 6, Loss: 0.69,  Training Accuracy: 0.83
# Epoch: 7, Loss: 0.61,  Training Accuracy: 0.85
# Epoch: 8, Loss: 0.54,  Training Accuracy: 0.88
# Epoch: 9, Loss: 0.47,  Training Accuracy: 0.90
# Epoch: 10, Loss: 0.43,  Training Accuracy: 0.91
# Epoch: 11, Loss: 0.41,  Training Accuracy: 0.91
# Finished Training

# %%
def inference (model, val_dl):
  correct_prediction = 0
  total_prediction = 0

  predictions = []
  labels_list = []
  file_paths = []

  # Disable gradient updates
  with torch.no_grad():
    for i, (inputs, labels, file_path) in enumerate(val_dl):

      # Normalize the inputs
      inputs_m, inputs_s = inputs.mean(), inputs.std()
      inputs = (inputs - inputs_m) / inputs_s

      # Get predictions
      outputs = model(inputs)

      # Get the predicted class with the highest score
      _, prediction = torch.max(outputs,1)
      rows, cols = torch.where(labels == 1)

      # Count of predictions that matched the target label
      correct_prediction += (prediction == cols).sum().item()
      total_prediction += prediction.shape[0]

      # Append the predictions, assigned labels and file paths
      predictions.append(prediction.cpu().numpy())
      labels_list.append(cols.cpu().numpy())
      file_paths.append(file_path)

  # Concatenate the saved predictions, assigned labels and file paths
  predictions = np.concatenate(predictions)
  labels_list = np.concatenate(labels_list)
  file_paths = np.concatenate(file_paths)

  # Print the file path, assigned label and prediction for each file
  for i in range(len(file_paths)):
    label_str = labelencoder.inverse_transform([labels_list[i]])[0]
    label_str = label_str.strip('[]')
    label_str = label_str.replace("'", "")

    pred_str = labelencoder.inverse_transform([predictions[i]])[0]
    pred_str = pred_str.strip('[]')
    pred_str = pred_str.replace("'", "")


    print(f'File path: {file_paths[i]}, Label: {label_str}, Prediction: {pred_str}, Guessed correctly: {label_str==pred_str}')

  acc = correct_prediction/total_prediction
  print('\n')
  print(f'Accuracy: {acc:.2f}')

inference(myModel, val_dl)
# Out:
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a055_120_130.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b013_130_140.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b106_140_150.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a100_270_280.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b113_20_30.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b019_70_80.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a106_120_130.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b095_110_120.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a107_270_280.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b037_170_180.wav, Label: library, Prediction: library, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a017_120_130.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a122_50_60.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b067_90_100.wav, Label: train, Prediction: car, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a130_190_200.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b078_60_70.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a105_130_140.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b114_130_140.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a023_190_200.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b069_240_250.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a018_80_90.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b073_130_140.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a023_130_140.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a103_130_140.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a096_150_160.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b055_117_127.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a010_110_120.wav, Label: residential_area, Prediction: beach, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b093_170_180.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a092_0_10.wav, Label: train, Prediction: cafe/restaurant, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a128_101_111.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b116_70_80.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b114_210_220.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a068_150_160.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a094_110_120.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b089_160_170.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a119_210_220.wav, Label: office, Prediction: forest_path, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b003_150_160.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a023_80_90.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a054_140_150.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b101_110_120.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a106_130_140.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a093_109_119.wav, Label: bus, Prediction: tram, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a057_110_120.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b047_100_110.wav, Label: library, Prediction: library, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a155_90_100.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b033_200_210.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b075_60_70.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b071_170_180.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b054_100_110.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a016_130_140.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b077_30_40.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b069_210_220.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b100_40_50.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a082_120_130.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a155_70_80.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b072_60_70.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a098_70_80.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a151_150_160.wav, Label: tram, Prediction: car, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b115_230_240.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a040_50_60.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b002_40_50.wav, Label: residential_area, Prediction: beach, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b004_100_110.wav, Label: residential_area, Prediction: park, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a086_20_30.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b050_110_120.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b097_170_180.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b095_170_180.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a116_68_78.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a126_220_230.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a006_170_180.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a096_260_270.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b053_130_140.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b034_100_110.wav, Label: library, Prediction: library, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b017_180_190.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a001_60_70.wav, Label: residential_area, Prediction: city_center, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b108_100_110.wav, Label: bus, Prediction: car, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b076_87_97.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a052_0_10.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a131_230_240.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a025_90_100.wav, Label: beach, Prediction: home, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a147_210_220.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a073_141_151.wav, Label: train, Prediction: train, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a154_140_150.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a085_70_80.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a089_160_170.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b110_130_140.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a101_160_170.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b107_70_80.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a060_60_70.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b095_230_240.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b106_100_110.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a096_220_230.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a107_170_180.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a015_30_40.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a155_170_180.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a079_200_210.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b096_270_280.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a007_100_110.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b015_10_20.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b001_130_140.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a151_170_180.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b029_120_130.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b016_20_30.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a006_50_60.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a130_130_140.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a106_140_150.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b075_130_140.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b010_0_10.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a083_70_80.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a148_180_190.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b093_80_90.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b008_190_200.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b107_100_110.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a142_217_227.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a157_187_197.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a057_60_70.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b037_20_30.wav, Label: library, Prediction: library, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a101_90_100.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b068_100_110.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a107_200_210.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b079_160_170.wav, Label: tram, Prediction: library, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b006_30_40.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a151_140_150.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a053_110_120.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b113_200_210.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b029_20_30.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a020_50_60.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a144_210_220.wav, Label: train, Prediction: train, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b112_20_30.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a100_40_50.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a123_120_130.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a108_230_240.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a059_0_10.wav, Label: forest_path, Prediction: beach, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b068_50_60.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b033_130_140.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a062_50_60.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a121_200_210.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a096_170_180.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a074_220_230.wav, Label: train, Prediction: train, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b085_170_180.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b020_60_70.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b096_280_290.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b021_10_20.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a058_110_120.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a143_130_140.wav, Label: library, Prediction: home, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b014_80_90.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a128_81_91.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a110_180_190.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a073_255_265.wav, Label: train, Prediction: train, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b024_70_80.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b061_80_90.wav, Label: train, Prediction: library, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a098_190_200.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b088_60_70.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a068_130_140.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b082_10_20.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b051_0_10.wav, Label: cafe/restaurant, Prediction: grocery_store, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b006_150_160.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a104_140_150.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a111_100_110.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a131_10_20.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b094_20_30.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a010_140_150.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a109_10_20.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a068_90_100.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b006_130_140.wav, Label: residential_area, Prediction: city_center, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b008_20_30.wav, Label: residential_area, Prediction: park, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a074_110_120.wav, Label: train, Prediction: train, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b006_190_200.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a013_40_50.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b075_0_10.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a010_10_20.wav, Label: residential_area, Prediction: beach, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b089_20_30.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a034_130_140.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b011_120_130.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b045_50_60.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b108_30_40.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b005_0_10.wav, Label: residential_area, Prediction: city_center, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a138_60_70.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a023_60_70.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a154_0_10.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b044_70_80.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b106_60_70.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b045_190_200.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a087_70_80.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a053_140_150.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a097_100_110.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a058_140_150.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b050_30_40.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a002_110_120.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a113_165_175.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a142_78_88.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b021_130_140.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a127_160_170.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a045_150_160.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b075_150_160.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b081_20_30.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a143_40_50.wav, Label: library, Prediction: library, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b042_120_130.wav, Label: library, Prediction: library, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b033_40_50.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a110_50_60.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b030_80_90.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a062_140_150.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a151_80_90.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a050_90_100.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a017_80_90.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a137_270_280.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b084_50_60.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b066_219_229.wav, Label: train, Prediction: train, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b071_150_160.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a082_50_60.wav, Label: cafe/restaurant, Prediction: city_center, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b105_230_240.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a021_200_210.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b052_30_40.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b092_0_10.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b020_150_160.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b109_20_30.wav, Label: bus, Prediction: bus, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a116_58_68.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b099_180_190.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a043_160_170.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b046_200_210.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b002_20_30.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a014_150_160.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a059_160_170.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a155_40_50.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b023_0_10.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b030_110_120.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b055_137_147.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b093_60_70.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a149_170_180.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b056_180_190.wav, Label: cafe/restaurant, Prediction: home, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a004_100_110.wav, Label: park, Prediction: park, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b057_160_170.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b048_50_60.wav, Label: library, Prediction: library, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a062_60_70.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a026_40_50.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a106_60_70.wav, Label: cafe/restaurant, Prediction: cafe/restaurant, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b102_30_40.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a089_0_10.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b072_180_190.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b096_140_150.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a120_130_140.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a128_11_21.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b048_40_50.wav, Label: library, Prediction: library, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b073_150_160.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a037_40_50.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b078_100_110.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a036_120_130.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a123_10_20.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a010_150_160.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b072_90_100.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a151_260_270.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b116_160_170.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b030_270_280.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b026_100_110.wav, Label: library, Prediction: library, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a113_265_275.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b053_260_270.wav, Label: office, Prediction: office, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a007_140_150.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a151_220_230.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b078_200_210.wav, Label: tram, Prediction: tram, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a009_100_110.wav, Label: residential_area, Prediction: residential_area, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a113_50_60.wav, Label: grocery_store, Prediction: grocery_store, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a137_200_210.wav, Label: car, Prediction: car, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a038_30_40.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a006_100_110.wav, Label: beach, Prediction: residential_area, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b098_0_10.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b091_172_182.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b041_170_180.wav, Label: library, Prediction: library, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/b072_20_30.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a024_40_50.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a098_100_110.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a025_20_30.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a157_10_20.wav, Label: metro_station, Prediction: metro_station, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/b030_10_20.wav, Label: home, Prediction: home, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a056_170_180.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b014_150_160.wav, Label: park, Prediction: bus, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a146_80_90.wav, Label: train, Prediction: tram, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b030_90_100.wav, Label: home, Prediction: library, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/audio4/a119_30_40.wav, Label: office, Prediction: forest_path, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b093_130_140.wav, Label: city_center, Prediction: city_center, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a026_10_20.wav, Label: beach, Prediction: beach, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/audio/a001_10_20.wav, Label: residential_area, Prediction: city_center, Guessed correctly: False
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/a055_170_180.wav, Label: forest_path, Prediction: forest_path, Guessed correctly: True
# File path: gdrive/My Drive/Deep learning/data set progetto/Audio2/b079_220_230.wav, Label: tram, Prediction: train, Guessed correctly: False
#
#
# Accuracy: 0.90
